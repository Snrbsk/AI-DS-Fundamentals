# %%
import pandas as pd
dataFrame = pd.read_excel("/Users/snrbsk/Downloads/Bilişim Topluluğu Görevli.xlsx")
dataFrame
# Out:
#                          Unvan          Adınız Soyadınız    Kurum  \
# 0             Topluluk Başkanı          Buğra       KAFA  GÖREVLİ
# 1     Topluluk Başkan Yardımcı           Soner     BAŞAK  GÖREVLİ
# 2                          NaN          Beyza      ARMAN  GÖREVLİ
# 3                          NaN           Enes      DOĞAN  GÖREVLİ
# 4                          NaN          Zeynep    KALELİ  GÖREVLİ
# 5                          NaN           Aslı      ÇELİK  GÖREVLİ
# 6   Toplululuk Akhisar Başkanı  Emirhan Selçuk    ATAKAN  GÖREVLİ
# 7                          NaN          Furkan     YAMAK  GÖREVLİ
# 8                          NaN          Gökçen     AKGÜL  GÖREVLİ
# 9                          NaN          Haniye  HOSSEİNİ  GÖREVLİ
# 10                         NaN          Hatice     AKGÜL  GÖREVLİ
# 11                         NaN      Mehmet Ali     GEZEN  GÖREVLİ
# 12                         NaN        Mustafa      SIDAN  GÖREVLİ
# ...

# %%
fullData = dataFrame.dropna(axis =1)
fullData
# Out:
#             Adınız Soyadınız    Kurum
# 0           Buğra       KAFA  GÖREVLİ
# 1            Soner     BAŞAK  GÖREVLİ
# 2           Beyza      ARMAN  GÖREVLİ
# 3            Enes      DOĞAN  GÖREVLİ
# 4           Zeynep    KALELİ  GÖREVLİ
# 5            Aslı      ÇELİK  GÖREVLİ
# 6   Emirhan Selçuk    ATAKAN  GÖREVLİ
# 7           Furkan     YAMAK  GÖREVLİ
# 8           Gökçen     AKGÜL  GÖREVLİ
# 9           Haniye  HOSSEİNİ  GÖREVLİ
# 10          Hatice     AKGÜL  GÖREVLİ
# 11      Mehmet Ali     GEZEN  GÖREVLİ
# 12        Mustafa      SIDAN  GÖREVLİ
# 13        Nuri Alp     MUTLU  GÖREVLİ
# 14  Fatih Berkant       EREN  GÖREVLİ
# 15           Çağan      ATAN  GÖREVLİ
# 16           Begüm     SEZER  GÖREVLİ
# 17        Emrecan      AKGÜL  GÖREVLİ
# 18           Hacer    SANCAR  GÖREVLİ
# 19           Kerem  KURTULDU  GÖREVLİ
# 20           Kübra    ÇELEBİ  GÖREVLİ
# 21           Deniz   KARAKAŞ  GÖREVLİ
# 22  Muhammed Emin      ŞANLI  GÖREVLİ
# 23       Ahmet Alp   ÖZDEMİR  GÖREVLİ
# ...

# %%
#To excel 
fullData.to_excel("Bilişim Aktif Üyeler.xlsx")

# %% [markdown]
# # Farklı formatlara da dönüştürülebilir.
